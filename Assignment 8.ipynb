# %% [raw]
# Ques 1.) Is the Python Standard Library included with PyInputPlus ?
#
# Solution :
#
# No, the Python Standard Library is not included with PyInputPlus. PyInputPlus is a third-party library that provides
# additional functionality for taking user input in Python, such as input validation and timeout handling. It is built on
# top of the Python Standard Library's input() function, but it does not include the entire standard library. When using
# PyInputPlus, we still have access to the Python Standard Library and can import and use its modules alongside PyInputPlus.

# %% [raw]
# Ques 2.) Why is PyInputPlus commonly imported with import pyinputplus as pypi ?
#
# Solution :
#
# The import statement import pyinputplus as pypi is commonly used to import PyInputPlus with an alias pypi.
#
# Using an alias allows us to refer to the PyInputPlus library with a shorter and more convenient name within our code. It
# helps in reducing the amount of typing required to access the library's functions and classes. Instead of typing pyinputplus.
# some_function(), we can simply use pypi.some_function().
#
# The choice of the alias pypi is arbitrary and can be any valid Python identifier. In this case, pypi might have been chosen
# to resemble the commonly used abbreviation for the Python Package Index (PyPI), which is the official repository for Python
# packages. However, it's important to note that the pypi alias used when importing PyInputPlus has no direct connection to the
# Python Package Index. It's simply a common choice for a shorter and more readable alias.

# %% [raw]
# # Ques 3.) How do you distinguish between inputInt() and inputFloat() ?
#
# Solution :
#
# In PyInputPlus, the functions inputInt() and inputFloat() are used to take user input and ensure that the input is a valid
# integer or floating-point number, respectively.
#
# To distinguish between inputInt() and inputFloat(), we need to consider the type of number we expect the user to enter.
#
# If we want to accept only integer values (whole numbers), we should use inputInt(). It will repeatedly prompt the user until
# they enter a valid integer value. If the user enters a non-integer value, an error message will be displayed, and they will be
# prompted again.
#
# Here's an example of using inputInt() :
#
# import pyinputplus as pypi
#
# num = pypi.inputInt("Enter an integer: ")
# print("You entered:", num)
#
# If we want to accept floating-point numbers (numbers with decimal places), we should use inputFloat(). It will prompt the
# user for input and validate that it is a valid floating-point number. If the user enters a non-numeric value or an invalid
# floating-point number, they will be prompted again.
#
# Here's an example of using inputFloat() :
#
# import pyinputplus as pypi
#
# num = pypi.inputFloat("Enter a floating-point number: ")
# print("You entered:", num)
#
# By choosing the appropriate function (inputInt() or inputFloat()), we can enforce the type of number we expect from the user
# and handle invalid input accordingly.

# %% [raw]
# Ques 4.) Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99 ?
#
# Solution :
#
# To ensure that the user enters a whole number between 0 and 99 using PyInputPlus, we can combine the inputInt() function with
# the min and max arguments.
#
# Here's an example code snippet that demonstrates this :
#
# import pyinputplus as pypi
#
# num = pypi.inputInt("Enter a number between 0 and 99: ", min=0, max=99)
# print("You entered:", num)
#
# In this example, the inputInt() function is used to prompt the user for input. The min argument is set to 0, and the max
# argument is set to 99. These arguments specify the acceptable range for the input. If the user enters a number that is less
# than 0 or greater than 99, they will be prompted again until a valid input within the specified range is provided.
#
# By specifying the min and max arguments, we can enforce the desired range for the input and ensure that the user enters a
# whole number between 0 and 99.

# %% [raw]
# Ques 5.) What is transferred to the keyword arguments allowRegexes and blockRegexes ?
#
# Solution :
#
# In PyInputPlus, the allowRegexes and blockRegexes keyword arguments are used to specify regular expressions that define
# patterns for allowed and blocked input, respectively.
#
# Here's an overview of what is transferred to these keyword arguments :
#
# 1.) 'allowRegexes' : This argument expects a list of regular expressions as its value. These regular expressions define
#     patterns that the user's input must match in order to be considered valid.
#
#     For eg, if we want to allow the user to input numbers starting with the digit '1', we can use the allowRegexes argument
#     as follows :
#
#         import pyinputplus as pypi
#         import re
#
#         num = pypi.inputNum("Enter a number starting with '1': ", allowRegexes=[re.compile(r'^1\d*')])
#         print("You entered:", num)
#
# In this case, the regular expression r'^1\d*' specifies that the input should start with '1' and can be followed by any number
# of digits.
#
# 2.) 'blockRegexes' : This argument expects a list of regular expressions as its value. These regular expressions define
#     patterns that the user's input must not match in order to be considered valid.
#
#     For eg, if we want to block any input that contains the letter 'a', we can use the blockRegexes argument as follows :
#
#         import pyinputplus as pypi
#         import re
#
#         text = pypi.inputStr("Enter some text (without the letter 'a'): ", blockRegexes=[re.compile(r'a')])
#         print("You entered:", text)
#
# In this case, the regular expression r'a' specifies that the input should not contain the letter 'a'.
#
# By using the allowRegexes and blockRegexes keyword arguments, we can define custom patterns to allow or block specific input
# based on regular expressions. This provides flexibility in validating and controlling user input.

# %% [raw]
# Ques 6.) If a blank input is entered three times, what does inputStr(limit=3) do ?
#
# Solution :
#
# When inputStr(limit=3) is used in PyInputPlus and a blank input is entered three times consecutively, it raises the pyinputplus.
# RetryLimitException exception.
#
# The limit parameter specifies the maximum number of retries or attempts allowed for the input. In this case, with limit=3,
# the user has up to three attempts to provide valid input.
#
# If the user enters a blank input (an empty string) three times in a row without providing any other input, the
# pyinputplus.RetryLimitException is raised. This exception indicates that the user has exceeded the maximum number of retries
# allowed.
#
# Here's an example that demonstrates this behavior :
#
# import pyinputplus as pypi
#
# try:
#     text = pypi.inputStr("Enter some text: ", limit=3)
#     print("You entered:", text)
# except pypi.RetryLimitException:
#     print("Maximum retry limit exceeded.")
#
# In this example, if the user enters a blank input three times in a row, the RetryLimitException will be caught, and the message
# "Maximum retry limit exceeded" will be displayed.
#
# Using the limit parameter allows us to define the maximum number of retries or attempts for the input, providing control over
# how many times the user can try to enter valid input before raising an exception.

# %% [raw]
# Ques 7.) If blank input is entered three times, what does inputStr(limit=3, default='hello') do ?
#
# Solution :
#
# When inputStr(limit=3, default='hello') is used in PyInputPlus and a blank input is entered three times consecutively, it
# returns the default value 'hello' instead of raising an exception.
#
# The limit parameter specifies the maximum number of retries or attempts allowed for the input, similar to the previous example.
# In this case, with limit=3, the user has up to three attempts to provide valid input.
#
# The default parameter is used to set a default value that will be returned if the user exceeds the retry limit or enters a
# blank input. In this case, the default value is 'hello'.
#
# Here's an example that demonstrates this behavior :
#
# import pyinputplus as pypi
#
# text = pypi.inputStr("Enter some text: ", limit=3, default='hello')
# print("You entered:", text)
#
# In this example, if the user enters a blank input three times in a row, the input function will return the default value
# 'hello'. The output will be "You entered : hello".
#
# By providing a default value, we can handle cases where the user exceeds the retry limit or enters invalid input, ensuring
# that our code receives a predefined value instead of raising an exception or returning None.
